# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install mne pyEDFlib pandas numpy scipy
# Out:
# Mounted at /content/drive
# Collecting mne
#   Downloading mne-1.11.0-py3-none-any.whl.metadata (15 kB)
# Collecting pyEDFlib
#   Downloading pyedflib-0.1.42-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.12/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from mne) (3.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mne) (25.0)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.12/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->mne) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->mne) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->mne) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->mne) (3.2.5)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.5->mne) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mne) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.11.12)
# Downloading mne-1.11.0-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 40.1 MB/s eta 0:00:00
# Downloading pyedflib-0.1.42-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 30.0 MB/s eta 0:00:00
# Installing collected packages: pyEDFlib, mne
# Successfully installed mne-1.11.0 pyEDFlib-0.1.42

# %%
import os
import pandas as pd
import numpy as np
import mne
from scipy.signal import find_peaks

# %%
events_root = "/content/drive/MyDrive/SeizeIT2/seizure_events"
ecg_root    = "/content/drive/MyDrive/SeizeIT2/ECG"
output_csv  = "/content/drive/MyDrive/SeizeIT2/preictal_rmssd_results.csv"

# %%
#square root of the mean of the squared differences between successive RR intervals
def compute_rmssd(rr_intervals_ms):
    if len(rr_intervals_ms) < 2: #need at least 2 RR intervals for RMSSD
        return np.nan
    diff = np.diff(rr_intervals_ms)
    return np.sqrt(np.mean(diff**2))

# %%
def extract_rr_intervals(ecg_data, sfreq):
    peaks, _ = find_peaks(ecg_data, distance=0.3 * sfreq)  #require 300ms between peaks for max 200bpm
    print(f"Peaks found in segment: {len(peaks)}")
    if len(peaks) < 2:
        return None
    peak_times = peaks / sfreq
    rr_intervals = np.diff(peak_times) * 1000  #convert to ms
    return rr_intervals

# %%
#main function
def get_preictal_rmssd(edf_path, seizure_onset_sec):
    raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
    raw.set_channel_types({'ECG SD': 'ecg'})
    #identify ECG channel
    ecg_chs = mne.pick_types(raw.info, ecg=True)
    if len(ecg_chs) == 0:
        return np.nan, np.nan, np.nan  #return 3 values

    ecg = raw.get_data()[ecg_chs[0]]
    sfreq = raw.info['sfreq']

    #60-second preictal window
    start_time = max(seizure_onset_sec - 60, 0)
    end_time = seizure_onset_sec

    #convert time to samples
    start_sample = int(start_time * sfreq)
    end_sample = int(end_time * sfreq)

    segment = ecg[start_sample:end_sample]
    if len(segment) < 1:
        return np.nan, start_time, end_time  #return 3 values

    rr = extract_rr_intervals(segment, sfreq)
    if rr is None:
        return np.nan, start_time, end_time  #return 3 values

    #compute RMSSD on the entire 60-second segment and return
    return compute_rmssd(rr), start_time, end_time

# %%
#match tsv to edf file
def match_edf_from_tsv_path(tsv_path):
    filename = os.path.basename(tsv_path)
    base = filename.replace("_events.tsv", "")
    expected_edf = base + "_ecg.edf"

    subject = filename.split("_")[0]  # sub-001
    edf_dir = os.path.join(ecg_root, subject)

    edf_path = os.path.join(edf_dir, expected_edf)
    return edf_path if os.path.exists(edf_path) else None

# %%
#main code

results = []

for subject_folder in sorted(os.listdir(events_root)): #each patient
    subj_path = os.path.join(events_root, subject_folder)
    ses_path = os.path.join(subj_path, "ses-01", "eeg")

    if not os.path.exists(ses_path):
        continue

    for tsv_file in sorted(os.listdir(ses_path)):
        if not tsv_file.endswith(".tsv"):
            continue

        tsv_path = os.path.join(ses_path, tsv_file)
        events = pd.read_csv(tsv_path, sep="\t")

        #fix possible capitalization issue
        seizure_rows = events[events["eventType"]\
                              .str.strip()\
                              .str.contains("sz", case=False, na=False)]

        print(f"{tsv_file}: Found {len(seizure_rows)} seizures")  #debug

        if len(seizure_rows) == 0:
            continue

        edf_path = match_edf_from_tsv_path(tsv_path)
        if edf_path is None:
            print("Missing EDF for:", tsv_path) #debug
            continue
        else:
            print("Found EDF:", edf_path)  #debug

        #compute RMSSD per seizure
        for idx, row in seizure_rows.iterrows():
            onset = row["onset"]
            rmssd, w_start, w_end = get_preictal_rmssd(edf_path, onset)

            #save results: each seizure is one row
            results.append({
                "subject": subject_folder,
                "events_file": tsv_file,
                "edf_file": os.path.basename(edf_path),
                "seizure_onset_sec": onset,
                "preictal_start_sec": w_start,
                "preictal_end_sec": w_end,
                "rmssd": rmssd
            })

        print(f"Processed: {tsv_path}")

#save results
df_results = pd.DataFrame(results)
df_results.to_csv(output_csv, index=False)
print(f"CSV saved to {output_csv}, total seizures processed: {len(results)}")
# Out:
# sub-001_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-001/sub-001_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 152
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-001/ses-01/eeg/sub-001_ses-01_task-szMonitoring_run-03_events.tsv
# sub-001_ses-01_task-szMonitoring_run-05_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-001/sub-001_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 142
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-001/ses-01/eeg/sub-001_ses-01_task-szMonitoring_run-05_events.tsv
# sub-001_ses-01_task-szMonitoring_run-07_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-001/sub-001_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 155
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-001/ses-01/eeg/sub-001_ses-01_task-szMonitoring_run-07_events.tsv
# sub-001_ses-01_task-szMonitoring_run-08_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-001/sub-001_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 153
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-001/ses-01/eeg/sub-001_ses-01_task-szMonitoring_run-08_events.tsv
# sub-002_ses-01_task-szMonitoring_run-01_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-002/sub-002_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 153
# Peaks found in segment: 142
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-01_events.tsv
# sub-002_ses-01_task-szMonitoring_run-02_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-002/sub-002_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 156
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-02_events.tsv
# sub-002_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-002/sub-002_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 158
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-03_events.tsv
# sub-002_ses-01_task-szMonitoring_run-05_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-002/sub-002_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 149
# Peaks found in segment: 147
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-05_events.tsv
# sub-002_ses-01_task-szMonitoring_run-06_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-002/sub-002_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 157
# Peaks found in segment: 140
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-06_events.tsv
# sub-002_ses-01_task-szMonitoring_run-09_events.tsv: Found 4 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-002/sub-002_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 149
# Peaks found in segment: 158
# Peaks found in segment: 142
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-09_events.tsv
# sub-002_ses-01_task-szMonitoring_run-10_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-002/sub-002_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 158
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-10_events.tsv
# sub-003_ses-01_task-szMonitoring_run-06_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-003/sub-003_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 159
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-003/ses-01/eeg/sub-003_ses-01_task-szMonitoring_run-06_events.tsv
# sub-004_ses-01_task-szMonitoring_run-01_events.tsv: Found 4 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-004/sub-004_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 165
# Peaks found in segment: 160
# Peaks found in segment: 142
# Peaks found in segment: 145
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-004/ses-01/eeg/sub-004_ses-01_task-szMonitoring_run-01_events.tsv
# sub-005_ses-01_task-szMonitoring_run-22_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-005/sub-005_ses-01_task-szMonitoring_run-22_ecg.edf
# Peaks found in segment: 163
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-005/ses-01/eeg/sub-005_ses-01_task-szMonitoring_run-22_events.tsv
# sub-005_ses-01_task-szMonitoring_run-23_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-005/sub-005_ses-01_task-szMonitoring_run-23_ecg.edf
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-005/ses-01/eeg/sub-005_ses-01_task-szMonitoring_run-23_events.tsv
# sub-007_ses-01_task-szMonitoring_run-03_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-007/sub-007_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 153
# Peaks found in segment: 170
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-007/ses-01/eeg/sub-007_ses-01_task-szMonitoring_run-03_events.tsv
# sub-008_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-008/sub-008_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 144
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-008/ses-01/eeg/sub-008_ses-01_task-szMonitoring_run-01_events.tsv
# sub-008_ses-01_task-szMonitoring_run-09_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-008/sub-008_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-008/ses-01/eeg/sub-008_ses-01_task-szMonitoring_run-09_events.tsv
# sub-009_ses-01_task-szMonitoring_run-09_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-009/sub-009_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 144
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-009/ses-01/eeg/sub-009_ses-01_task-szMonitoring_run-09_events.tsv
# sub-010_ses-01_task-szMonitoring_run-08_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-010/sub-010_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 172
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-010/ses-01/eeg/sub-010_ses-01_task-szMonitoring_run-08_events.tsv
# sub-011_ses-01_task-szMonitoring_run-02_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-011/sub-011_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 72
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-011/ses-01/eeg/sub-011_ses-01_task-szMonitoring_run-02_events.tsv
# sub-011_ses-01_task-szMonitoring_run-03_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-011/sub-011_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 161
# Peaks found in segment: 131
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-011/ses-01/eeg/sub-011_ses-01_task-szMonitoring_run-03_events.tsv
# sub-011_ses-01_task-szMonitoring_run-05_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-011/sub-011_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 156
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-011/ses-01/eeg/sub-011_ses-01_task-szMonitoring_run-05_events.tsv
# sub-013_ses-01_task-szMonitoring_run-01_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-013/sub-013_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 155
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-013/ses-01/eeg/sub-013_ses-01_task-szMonitoring_run-01_events.tsv
# sub-014_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-014/sub-014_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 145
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-014/ses-01/eeg/sub-014_ses-01_task-szMonitoring_run-01_events.tsv
# sub-014_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-014/sub-014_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 149
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-014/ses-01/eeg/sub-014_ses-01_task-szMonitoring_run-03_events.tsv
# sub-015_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-015/sub-015_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 180
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-015/ses-01/eeg/sub-015_ses-01_task-szMonitoring_run-01_events.tsv
# sub-015_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-015/sub-015_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-015/ses-01/eeg/sub-015_ses-01_task-szMonitoring_run-03_events.tsv
# sub-015_ses-01_task-szMonitoring_run-04_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-015/sub-015_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 153
# Peaks found in segment: 154
# Peaks found in segment: 172
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-015/ses-01/eeg/sub-015_ses-01_task-szMonitoring_run-04_events.tsv
# sub-015_ses-01_task-szMonitoring_run-06_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-015/sub-015_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-015/ses-01/eeg/sub-015_ses-01_task-szMonitoring_run-06_events.tsv
# sub-015_ses-01_task-szMonitoring_run-08_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-015/sub-015_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 168
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-015/ses-01/eeg/sub-015_ses-01_task-szMonitoring_run-08_events.tsv
# sub-015_ses-01_task-szMonitoring_run-09_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-015/sub-015_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 153
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-015/ses-01/eeg/sub-015_ses-01_task-szMonitoring_run-09_events.tsv
# sub-016_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-016/sub-016_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 164
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-016/ses-01/eeg/sub-016_ses-01_task-szMonitoring_run-03_events.tsv
# sub-017_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-017/sub-017_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 163
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-017/ses-01/eeg/sub-017_ses-01_task-szMonitoring_run-01_events.tsv
# sub-018_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-018/sub-018_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 153
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-018/ses-01/eeg/sub-018_ses-01_task-szMonitoring_run-03_events.tsv
# sub-019_ses-01_task-szMonitoring_run-07_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-019/sub-019_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 151
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-019/ses-01/eeg/sub-019_ses-01_task-szMonitoring_run-07_events.tsv
# sub-020_ses-01_task-szMonitoring_run-05_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-020/sub-020_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 165
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-020/ses-01/eeg/sub-020_ses-01_task-szMonitoring_run-05_events.tsv
# sub-021_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-021/sub-021_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 162
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-021/ses-01/eeg/sub-021_ses-01_task-szMonitoring_run-01_events.tsv
# sub-021_ses-01_task-szMonitoring_run-04_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-021/sub-021_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 149
# Peaks found in segment: 152
# Peaks found in segment: 152
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-021/ses-01/eeg/sub-021_ses-01_task-szMonitoring_run-04_events.tsv
# sub-022_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-022/sub-022_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 140
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-022/ses-01/eeg/sub-022_ses-01_task-szMonitoring_run-03_events.tsv
# sub-022_ses-01_task-szMonitoring_run-04_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-022/sub-022_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 157
# Peaks found in segment: 151
# Peaks found in segment: 167
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-022/ses-01/eeg/sub-022_ses-01_task-szMonitoring_run-04_events.tsv
# sub-022_ses-01_task-szMonitoring_run-06_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-022/sub-022_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 148
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-022/ses-01/eeg/sub-022_ses-01_task-szMonitoring_run-06_events.tsv
# sub-022_ses-01_task-szMonitoring_run-10_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-022/sub-022_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-022/ses-01/eeg/sub-022_ses-01_task-szMonitoring_run-10_events.tsv
# sub-023_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-023/sub-023_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 178
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-023/ses-01/eeg/sub-023_ses-01_task-szMonitoring_run-03_events.tsv
# sub-024_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-024/sub-024_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 151
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-024/ses-01/eeg/sub-024_ses-01_task-szMonitoring_run-01_events.tsv
# sub-024_ses-01_task-szMonitoring_run-07_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-024/sub-024_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 156
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-024/ses-01/eeg/sub-024_ses-01_task-szMonitoring_run-07_events.tsv
# sub-025_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-025/sub-025_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 166
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-025/ses-01/eeg/sub-025_ses-01_task-szMonitoring_run-03_events.tsv
# sub-025_ses-01_task-szMonitoring_run-04_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-025/sub-025_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 158
# Peaks found in segment: 144
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-025/ses-01/eeg/sub-025_ses-01_task-szMonitoring_run-04_events.tsv
# sub-026_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-026/sub-026_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 146
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-026/ses-01/eeg/sub-026_ses-01_task-szMonitoring_run-01_events.tsv
# sub-026_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-026/sub-026_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 146
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-026/ses-01/eeg/sub-026_ses-01_task-szMonitoring_run-03_events.tsv
# sub-026_ses-01_task-szMonitoring_run-04_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-026/sub-026_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 152
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-026/ses-01/eeg/sub-026_ses-01_task-szMonitoring_run-04_events.tsv
# sub-026_ses-01_task-szMonitoring_run-06_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-026/sub-026_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 143
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-026/ses-01/eeg/sub-026_ses-01_task-szMonitoring_run-06_events.tsv
# sub-027_ses-01_task-szMonitoring_run-07_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-027/sub-027_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 179
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-027/ses-01/eeg/sub-027_ses-01_task-szMonitoring_run-07_events.tsv
# sub-028_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-028/sub-028_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 161
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-028/ses-01/eeg/sub-028_ses-01_task-szMonitoring_run-01_events.tsv
# sub-028_ses-01_task-szMonitoring_run-04_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-028/sub-028_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 160
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-028/ses-01/eeg/sub-028_ses-01_task-szMonitoring_run-04_events.tsv
# sub-028_ses-01_task-szMonitoring_run-05_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-028/sub-028_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-028/ses-01/eeg/sub-028_ses-01_task-szMonitoring_run-05_events.tsv
# sub-029_ses-01_task-szMonitoring_run-08_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-029/sub-029_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 142
# Peaks found in segment: 143
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-029/ses-01/eeg/sub-029_ses-01_task-szMonitoring_run-08_events.tsv
# sub-029_ses-01_task-szMonitoring_run-10_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-029/sub-029_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 151
# Peaks found in segment: 150
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-029/ses-01/eeg/sub-029_ses-01_task-szMonitoring_run-10_events.tsv
# sub-030_ses-01_task-szMonitoring_run-03_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-030/sub-030_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 173
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-030/ses-01/eeg/sub-030_ses-01_task-szMonitoring_run-03_events.tsv
# sub-030_ses-01_task-szMonitoring_run-04_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-030/sub-030_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 151
# Peaks found in segment: 136
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-030/ses-01/eeg/sub-030_ses-01_task-szMonitoring_run-04_events.tsv
# sub-030_ses-01_task-szMonitoring_run-05_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-030/sub-030_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 144
# Peaks found in segment: 141
# Peaks found in segment: 141
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-030/ses-01/eeg/sub-030_ses-01_task-szMonitoring_run-05_events.tsv
# sub-031_ses-01_task-szMonitoring_run-03_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-031/sub-031_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 149
# Peaks found in segment: 160
# Peaks found in segment: 165
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-031/ses-01/eeg/sub-031_ses-01_task-szMonitoring_run-03_events.tsv
# sub-032_ses-01_task-szMonitoring_run-05_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-032/sub-032_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 166
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-032/ses-01/eeg/sub-032_ses-01_task-szMonitoring_run-05_events.tsv
# sub-033_ses-01_task-szMonitoring_run-12_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-033/sub-033_ses-01_task-szMonitoring_run-12_ecg.edf
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-033/ses-01/eeg/sub-033_ses-01_task-szMonitoring_run-12_events.tsv
# sub-034_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-034/sub-034_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 136
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-034/ses-01/eeg/sub-034_ses-01_task-szMonitoring_run-01_events.tsv
# sub-034_ses-01_task-szMonitoring_run-03_events.tsv: Found 7 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-034/sub-034_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 143
# Peaks found in segment: 148
# Peaks found in segment: 149
# Peaks found in segment: 138
# Peaks found in segment: 149
# Peaks found in segment: 148
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-034/ses-01/eeg/sub-034_ses-01_task-szMonitoring_run-03_events.tsv
# sub-034_ses-01_task-szMonitoring_run-04_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-034/sub-034_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 161
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-034/ses-01/eeg/sub-034_ses-01_task-szMonitoring_run-04_events.tsv
# sub-034_ses-01_task-szMonitoring_run-07_events.tsv: Found 6 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-034/sub-034_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 144
# Peaks found in segment: 159
# Peaks found in segment: 160
# Peaks found in segment: 152
# Peaks found in segment: 138
# Peaks found in segment: 156
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-034/ses-01/eeg/sub-034_ses-01_task-szMonitoring_run-07_events.tsv
# sub-034_ses-01_task-szMonitoring_run-08_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-034/sub-034_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 143
# Peaks found in segment: 151
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-034/ses-01/eeg/sub-034_ses-01_task-szMonitoring_run-08_events.tsv
# sub-034_ses-01_task-szMonitoring_run-09_events.tsv: Found 11 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-034/sub-034_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 155
# Peaks found in segment: 146
# Peaks found in segment: 149
# Peaks found in segment: 141
# Peaks found in segment: 142
# Peaks found in segment: 157
# Peaks found in segment: 160
# Peaks found in segment: 146
# Peaks found in segment: 143
# Peaks found in segment: 147
# Peaks found in segment: 157
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-034/ses-01/eeg/sub-034_ses-01_task-szMonitoring_run-09_events.tsv
# sub-034_ses-01_task-szMonitoring_run-10_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-034/sub-034_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 150
# Peaks found in segment: 145
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-034/ses-01/eeg/sub-034_ses-01_task-szMonitoring_run-10_events.tsv
# sub-035_ses-01_task-szMonitoring_run-03_events.tsv: Found 13 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 167
# Peaks found in segment: 154
# Peaks found in segment: 166
# Peaks found in segment: 157
# Peaks found in segment: 160
# Peaks found in segment: 162
# Peaks found in segment: 164
# Peaks found in segment: 164
# Peaks found in segment: 160
# Peaks found in segment: 166
# Peaks found in segment: 168
# Peaks found in segment: 163
# Peaks found in segment: 167
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-03_events.tsv
# sub-035_ses-01_task-szMonitoring_run-04_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 162
# Peaks found in segment: 168
# Peaks found in segment: 167
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-04_events.tsv
# sub-035_ses-01_task-szMonitoring_run-06_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 169
# Peaks found in segment: 157
# Peaks found in segment: 155
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-06_events.tsv
# sub-035_ses-01_task-szMonitoring_run-07_events.tsv: Found 14 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 164
# Peaks found in segment: 169
# Peaks found in segment: 168
# Peaks found in segment: 167
# Peaks found in segment: 166
# Peaks found in segment: 165
# Peaks found in segment: 166
# Peaks found in segment: 166
# Peaks found in segment: 171
# Peaks found in segment: 168
# Peaks found in segment: 171
# Peaks found in segment: 164
# Peaks found in segment: 166
# Peaks found in segment: 161
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-07_events.tsv
# sub-035_ses-01_task-szMonitoring_run-09_events.tsv: Found 4 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 160
# Peaks found in segment: 167
# Peaks found in segment: 170
# Peaks found in segment: 167
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-09_events.tsv
# sub-035_ses-01_task-szMonitoring_run-11_events.tsv: Found 12 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-11_ecg.edf
# Peaks found in segment: 155
# Peaks found in segment: 171
# Peaks found in segment: 159
# Peaks found in segment: 171
# Peaks found in segment: 158
# Peaks found in segment: 164
# Peaks found in segment: 165
# Peaks found in segment: 160
# Peaks found in segment: 163
# Peaks found in segment: 159
# Peaks found in segment: 164
# Peaks found in segment: 168
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-11_events.tsv
# sub-035_ses-01_task-szMonitoring_run-12_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-12_ecg.edf
# Peaks found in segment: 167
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-12_events.tsv
# sub-035_ses-01_task-szMonitoring_run-14_events.tsv: Found 5 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-035/sub-035_ses-01_task-szMonitoring_run-14_ecg.edf
# Peaks found in segment: 151
# Peaks found in segment: 171
# Peaks found in segment: 158
# Peaks found in segment: 154
# Peaks found in segment: 157
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-035/ses-01/eeg/sub-035_ses-01_task-szMonitoring_run-14_events.tsv
# sub-036_ses-01_task-szMonitoring_run-01_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-036/sub-036_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 169
# Peaks found in segment: 166
# Peaks found in segment: 162
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-036/ses-01/eeg/sub-036_ses-01_task-szMonitoring_run-01_events.tsv
# sub-038_ses-01_task-szMonitoring_run-07_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-038/sub-038_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 141
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-038/ses-01/eeg/sub-038_ses-01_task-szMonitoring_run-07_events.tsv
# sub-039_ses-01_task-szMonitoring_run-01_events.tsv: Found 12 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-039/sub-039_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 167
# Peaks found in segment: 162
# Peaks found in segment: 148
# Peaks found in segment: 156
# Peaks found in segment: 158
# Peaks found in segment: 158
# Peaks found in segment: 162
# Peaks found in segment: 155
# Peaks found in segment: 166
# Peaks found in segment: 158
# Peaks found in segment: 155
# Peaks found in segment: 163
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-039/ses-01/eeg/sub-039_ses-01_task-szMonitoring_run-01_events.tsv
# sub-039_ses-01_task-szMonitoring_run-02_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-039/sub-039_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 163
# Peaks found in segment: 131
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-039/ses-01/eeg/sub-039_ses-01_task-szMonitoring_run-02_events.tsv
# sub-039_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-039/sub-039_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-039/ses-01/eeg/sub-039_ses-01_task-szMonitoring_run-03_events.tsv
# sub-039_ses-01_task-szMonitoring_run-04_events.tsv: Found 22 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-039/sub-039_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 155
# Peaks found in segment: 162
# Peaks found in segment: 162
# Peaks found in segment: 161
# Peaks found in segment: 148
# Peaks found in segment: 164
# Peaks found in segment: 161
# Peaks found in segment: 162
# Peaks found in segment: 157
# Peaks found in segment: 166
# Peaks found in segment: 164
# Peaks found in segment: 158
# Peaks found in segment: 159
# Peaks found in segment: 161
# Peaks found in segment: 157
# Peaks found in segment: 155
# Peaks found in segment: 164
# Peaks found in segment: 161
# Peaks found in segment: 163
# Peaks found in segment: 156
# Peaks found in segment: 158
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-039/ses-01/eeg/sub-039_ses-01_task-szMonitoring_run-04_events.tsv
# sub-039_ses-01_task-szMonitoring_run-06_events.tsv: Found 17 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-039/sub-039_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 166
# Peaks found in segment: 164
# Peaks found in segment: 167
# Peaks found in segment: 158
# Peaks found in segment: 151
# Peaks found in segment: 166
# Peaks found in segment: 162
# Peaks found in segment: 153
# Peaks found in segment: 155
# Peaks found in segment: 166
# Peaks found in segment: 161
# Peaks found in segment: 154
# Peaks found in segment: 161
# Peaks found in segment: 154
# Peaks found in segment: 161
# Peaks found in segment: 163
# Peaks found in segment: 159
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-039/ses-01/eeg/sub-039_ses-01_task-szMonitoring_run-06_events.tsv
# sub-039_ses-01_task-szMonitoring_run-08_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-039/sub-039_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-039/ses-01/eeg/sub-039_ses-01_task-szMonitoring_run-08_events.tsv
# sub-039_ses-01_task-szMonitoring_run-09_events.tsv: Found 20 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-039/sub-039_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 141
# Peaks found in segment: 155
# Peaks found in segment: 158
# Peaks found in segment: 156
# Peaks found in segment: 158
# Peaks found in segment: 161
# Peaks found in segment: 160
# Peaks found in segment: 163
# Peaks found in segment: 157
# Peaks found in segment: 158
# Peaks found in segment: 158
# Peaks found in segment: 162
# Peaks found in segment: 159
# Peaks found in segment: 154
# Peaks found in segment: 154
# Peaks found in segment: 160
# Peaks found in segment: 156
# Peaks found in segment: 156
# Peaks found in segment: 157
# Peaks found in segment: 157
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-039/ses-01/eeg/sub-039_ses-01_task-szMonitoring_run-09_events.tsv
# sub-041_ses-01_task-szMonitoring_run-01_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-041/sub-041_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 175
# Peaks found in segment: 163
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-041/ses-01/eeg/sub-041_ses-01_task-szMonitoring_run-01_events.tsv
# sub-042_ses-01_task-szMonitoring_run-04_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-042/sub-042_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 107
# Peaks found in segment: 117
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-042/ses-01/eeg/sub-042_ses-01_task-szMonitoring_run-04_events.tsv
# sub-042_ses-01_task-szMonitoring_run-08_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-042/sub-042_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 118
# Peaks found in segment: 154
# Peaks found in segment: 140
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-042/ses-01/eeg/sub-042_ses-01_task-szMonitoring_run-08_events.tsv
# sub-043_ses-01_task-szMonitoring_run-05_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-043/sub-043_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 156
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-043/ses-01/eeg/sub-043_ses-01_task-szMonitoring_run-05_events.tsv
# sub-043_ses-01_task-szMonitoring_run-06_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-043/sub-043_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 136
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-043/ses-01/eeg/sub-043_ses-01_task-szMonitoring_run-06_events.tsv
# sub-043_ses-01_task-szMonitoring_run-07_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-043/sub-043_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 0
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-043/ses-01/eeg/sub-043_ses-01_task-szMonitoring_run-07_events.tsv
# sub-043_ses-01_task-szMonitoring_run-08_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-043/sub-043_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 116
# Peaks found in segment: 119
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-043/ses-01/eeg/sub-043_ses-01_task-szMonitoring_run-08_events.tsv
# sub-044_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-044/sub-044_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 160
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-044/ses-01/eeg/sub-044_ses-01_task-szMonitoring_run-01_events.tsv
# sub-044_ses-01_task-szMonitoring_run-05_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-044/sub-044_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 152
# Peaks found in segment: 161
# Peaks found in segment: 161
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-044/ses-01/eeg/sub-044_ses-01_task-szMonitoring_run-05_events.tsv
# sub-045_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-045/sub-045_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 152
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-045/ses-01/eeg/sub-045_ses-01_task-szMonitoring_run-03_events.tsv
# sub-045_ses-01_task-szMonitoring_run-09_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-045/sub-045_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 156
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-045/ses-01/eeg/sub-045_ses-01_task-szMonitoring_run-09_events.tsv
# sub-046_ses-01_task-szMonitoring_run-01_events.tsv: Found 4 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-046/sub-046_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 151
# Peaks found in segment: 158
# Peaks found in segment: 145
# Peaks found in segment: 149
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-046/ses-01/eeg/sub-046_ses-01_task-szMonitoring_run-01_events.tsv
# sub-047_ses-01_task-szMonitoring_run-01_events.tsv: Found 6 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-047/sub-047_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 161
# Peaks found in segment: 113
# Peaks found in segment: 158
# Peaks found in segment: 146
# Peaks found in segment: 163
# Peaks found in segment: 155
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-047/ses-01/eeg/sub-047_ses-01_task-szMonitoring_run-01_events.tsv
# sub-047_ses-01_task-szMonitoring_run-02_events.tsv: Found 12 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-047/sub-047_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 142
# Peaks found in segment: 144
# Peaks found in segment: 147
# Peaks found in segment: 157
# Peaks found in segment: 140
# Peaks found in segment: 149
# Peaks found in segment: 140
# Peaks found in segment: 155
# Peaks found in segment: 164
# Peaks found in segment: 170
# Peaks found in segment: 157
# Peaks found in segment: 159
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-047/ses-01/eeg/sub-047_ses-01_task-szMonitoring_run-02_events.tsv
# sub-047_ses-01_task-szMonitoring_run-03_events.tsv: Found 5 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-047/sub-047_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 174
# Peaks found in segment: 166
# Peaks found in segment: 162
# Peaks found in segment: 161
# Peaks found in segment: 155
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-047/ses-01/eeg/sub-047_ses-01_task-szMonitoring_run-03_events.tsv
# sub-047_ses-01_task-szMonitoring_run-04_events.tsv: Found 21 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-047/sub-047_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 159
# Peaks found in segment: 157
# Peaks found in segment: 157
# Peaks found in segment: 157
# Peaks found in segment: 152
# Peaks found in segment: 151
# Peaks found in segment: 157
# Peaks found in segment: 155
# Peaks found in segment: 157
# Peaks found in segment: 156
# Peaks found in segment: 154
# Peaks found in segment: 157
# Peaks found in segment: 148
# Peaks found in segment: 138
# Peaks found in segment: 147
# Peaks found in segment: 152
# Peaks found in segment: 141
# Peaks found in segment: 141
# Peaks found in segment: 155
# Peaks found in segment: 151
# Peaks found in segment: 150
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-047/ses-01/eeg/sub-047_ses-01_task-szMonitoring_run-04_events.tsv
# sub-047_ses-01_task-szMonitoring_run-06_events.tsv: Found 6 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-047/sub-047_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 159
# Peaks found in segment: 154
# Peaks found in segment: 134
# Peaks found in segment: 116
# Peaks found in segment: 115
# Peaks found in segment: 144
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-047/ses-01/eeg/sub-047_ses-01_task-szMonitoring_run-06_events.tsv
# sub-047_ses-01_task-szMonitoring_run-07_events.tsv: Found 14 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-047/sub-047_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 163
# Peaks found in segment: 155
# Peaks found in segment: 157
# Peaks found in segment: 164
# Peaks found in segment: 143
# Peaks found in segment: 128
# Peaks found in segment: 132
# Peaks found in segment: 157
# Peaks found in segment: 150
# Peaks found in segment: 152
# Peaks found in segment: 153
# Peaks found in segment: 158
# Peaks found in segment: 142
# Peaks found in segment: 125
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-047/ses-01/eeg/sub-047_ses-01_task-szMonitoring_run-07_events.tsv
# sub-050_ses-01_task-szMonitoring_run-05_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-050/sub-050_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 151
# Peaks found in segment: 159
# Peaks found in segment: 158
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-050/ses-01/eeg/sub-050_ses-01_task-szMonitoring_run-05_events.tsv
# sub-051_ses-01_task-szMonitoring_run-01_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-051/sub-051_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 155
# Peaks found in segment: 157
# Peaks found in segment: 138
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-051/ses-01/eeg/sub-051_ses-01_task-szMonitoring_run-01_events.tsv
# sub-051_ses-01_task-szMonitoring_run-02_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-051/sub-051_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 142
# Peaks found in segment: 161
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-051/ses-01/eeg/sub-051_ses-01_task-szMonitoring_run-02_events.tsv
# sub-052_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-052/sub-052_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 165
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-052/ses-01/eeg/sub-052_ses-01_task-szMonitoring_run-01_events.tsv
# sub-052_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-052/sub-052_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 174
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-052/ses-01/eeg/sub-052_ses-01_task-szMonitoring_run-03_events.tsv
# sub-052_ses-01_task-szMonitoring_run-05_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-052/sub-052_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 168
# Peaks found in segment: 159
# Peaks found in segment: 179
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-052/ses-01/eeg/sub-052_ses-01_task-szMonitoring_run-05_events.tsv
# sub-052_ses-01_task-szMonitoring_run-07_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-052/sub-052_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 169
# Peaks found in segment: 168
# Peaks found in segment: 145
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-052/ses-01/eeg/sub-052_ses-01_task-szMonitoring_run-07_events.tsv
# sub-052_ses-01_task-szMonitoring_run-08_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-052/sub-052_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 166
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-052/ses-01/eeg/sub-052_ses-01_task-szMonitoring_run-08_events.tsv
# sub-053_ses-01_task-szMonitoring_run-02_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-053/sub-053_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 157
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-053/ses-01/eeg/sub-053_ses-01_task-szMonitoring_run-02_events.tsv
# sub-053_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-053/sub-053_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 138
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-053/ses-01/eeg/sub-053_ses-01_task-szMonitoring_run-03_events.tsv
# sub-053_ses-01_task-szMonitoring_run-04_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-053/sub-053_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 150
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-053/ses-01/eeg/sub-053_ses-01_task-szMonitoring_run-04_events.tsv
# sub-055_ses-01_task-szMonitoring_run-01_events.tsv: Found 5 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-055/sub-055_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 152
# Peaks found in segment: 147
# Peaks found in segment: 148
# Peaks found in segment: 153
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-055/ses-01/eeg/sub-055_ses-01_task-szMonitoring_run-01_events.tsv
# sub-055_ses-01_task-szMonitoring_run-02_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-055/sub-055_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 138
# Peaks found in segment: 144
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-055/ses-01/eeg/sub-055_ses-01_task-szMonitoring_run-02_events.tsv
# sub-055_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-055/sub-055_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 132
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-055/ses-01/eeg/sub-055_ses-01_task-szMonitoring_run-03_events.tsv
# sub-056_ses-01_task-szMonitoring_run-02_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-056/sub-056_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 159
# Peaks found in segment: 160
# Peaks found in segment: 143
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-056/ses-01/eeg/sub-056_ses-01_task-szMonitoring_run-02_events.tsv
# sub-056_ses-01_task-szMonitoring_run-03_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-056/sub-056_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 152
# Peaks found in segment: 161
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-056/ses-01/eeg/sub-056_ses-01_task-szMonitoring_run-03_events.tsv
# sub-056_ses-01_task-szMonitoring_run-04_events.tsv: Found 6 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-056/sub-056_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 17
# Peaks found in segment: 138
# Peaks found in segment: 142
# Peaks found in segment: 145
# Peaks found in segment: 138
# Peaks found in segment: 159
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-056/ses-01/eeg/sub-056_ses-01_task-szMonitoring_run-04_events.tsv
# sub-056_ses-01_task-szMonitoring_run-05_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-056/sub-056_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 167
# Peaks found in segment: 158
# ...
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-113/sub-113_ses-01_task-szMonitoring_run-04_ecg.edf
# Peaks found in segment: 154
# Peaks found in segment: 142
# Peaks found in segment: 148
# Peaks found in segment: 152
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-113/ses-01/eeg/sub-113_ses-01_task-szMonitoring_run-04_events.tsv
# sub-113_ses-01_task-szMonitoring_run-05_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-113/sub-113_ses-01_task-szMonitoring_run-05_ecg.edf
# Peaks found in segment: 154
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-113/ses-01/eeg/sub-113_ses-01_task-szMonitoring_run-05_events.tsv
# sub-113_ses-01_task-szMonitoring_run-06_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-113/sub-113_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 150
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-113/ses-01/eeg/sub-113_ses-01_task-szMonitoring_run-06_events.tsv
# sub-113_ses-01_task-szMonitoring_run-08_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-113/sub-113_ses-01_task-szMonitoring_run-08_ecg.edf
# Peaks found in segment: 141
# Peaks found in segment: 155
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-113/ses-01/eeg/sub-113_ses-01_task-szMonitoring_run-08_events.tsv
# sub-114_ses-01_task-szMonitoring_run-02_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-114/sub-114_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 142
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-114/ses-01/eeg/sub-114_ses-01_task-szMonitoring_run-02_events.tsv
# sub-114_ses-01_task-szMonitoring_run-06_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-114/sub-114_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 147
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-114/ses-01/eeg/sub-114_ses-01_task-szMonitoring_run-06_events.tsv
# sub-114_ses-01_task-szMonitoring_run-10_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-114/sub-114_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 149
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-114/ses-01/eeg/sub-114_ses-01_task-szMonitoring_run-10_events.tsv
# sub-114_ses-01_task-szMonitoring_run-11_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-114/sub-114_ses-01_task-szMonitoring_run-11_ecg.edf
# Peaks found in segment: 147
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-114/ses-01/eeg/sub-114_ses-01_task-szMonitoring_run-11_events.tsv
# sub-115_ses-01_task-szMonitoring_run-09_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-115/sub-115_ses-01_task-szMonitoring_run-09_ecg.edf
# Peaks found in segment: 126
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-115/ses-01/eeg/sub-115_ses-01_task-szMonitoring_run-09_events.tsv
# sub-115_ses-01_task-szMonitoring_run-49_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-115/sub-115_ses-01_task-szMonitoring_run-49_ecg.edf
# Peaks found in segment: 126
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-115/ses-01/eeg/sub-115_ses-01_task-szMonitoring_run-49_events.tsv
# sub-115_ses-01_task-szMonitoring_run-52_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-115/sub-115_ses-01_task-szMonitoring_run-52_ecg.edf
# Peaks found in segment: 150
# Peaks found in segment: 145
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-115/ses-01/eeg/sub-115_ses-01_task-szMonitoring_run-52_events.tsv
# sub-115_ses-01_task-szMonitoring_run-55_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-115/sub-115_ses-01_task-szMonitoring_run-55_ecg.edf
# Peaks found in segment: 136
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-115/ses-01/eeg/sub-115_ses-01_task-szMonitoring_run-55_events.tsv
# sub-115_ses-01_task-szMonitoring_run-57_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-115/sub-115_ses-01_task-szMonitoring_run-57_ecg.edf
# Peaks found in segment: 134
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-115/ses-01/eeg/sub-115_ses-01_task-szMonitoring_run-57_events.tsv
# sub-116_ses-01_task-szMonitoring_run-06_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-116/sub-116_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 149
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-116/ses-01/eeg/sub-116_ses-01_task-szMonitoring_run-06_events.tsv
# sub-116_ses-01_task-szMonitoring_run-18_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-116/sub-116_ses-01_task-szMonitoring_run-18_ecg.edf
# Peaks found in segment: 153
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-116/ses-01/eeg/sub-116_ses-01_task-szMonitoring_run-18_events.tsv
# sub-116_ses-01_task-szMonitoring_run-19_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-116/sub-116_ses-01_task-szMonitoring_run-19_ecg.edf
# Peaks found in segment: 156
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-116/ses-01/eeg/sub-116_ses-01_task-szMonitoring_run-19_events.tsv
# sub-116_ses-01_task-szMonitoring_run-24_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-116/sub-116_ses-01_task-szMonitoring_run-24_ecg.edf
# Peaks found in segment: 143
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-116/ses-01/eeg/sub-116_ses-01_task-szMonitoring_run-24_events.tsv
# sub-116_ses-01_task-szMonitoring_run-25_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-116/sub-116_ses-01_task-szMonitoring_run-25_ecg.edf
# Peaks found in segment: 147
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-116/ses-01/eeg/sub-116_ses-01_task-szMonitoring_run-25_events.tsv
# sub-116_ses-01_task-szMonitoring_run-26_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-116/sub-116_ses-01_task-szMonitoring_run-26_ecg.edf
# Peaks found in segment: 151
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-116/ses-01/eeg/sub-116_ses-01_task-szMonitoring_run-26_events.tsv
# sub-116_ses-01_task-szMonitoring_run-27_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-116/sub-116_ses-01_task-szMonitoring_run-27_ecg.edf
# Peaks found in segment: 138
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-116/ses-01/eeg/sub-116_ses-01_task-szMonitoring_run-27_events.tsv
# sub-117_ses-01_task-szMonitoring_run-06_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-117/sub-117_ses-01_task-szMonitoring_run-06_ecg.edf
# Peaks found in segment: 146
# Peaks found in segment: 144
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-117/ses-01/eeg/sub-117_ses-01_task-szMonitoring_run-06_events.tsv
# sub-117_ses-01_task-szMonitoring_run-07_events.tsv: Found 5 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-117/sub-117_ses-01_task-szMonitoring_run-07_ecg.edf
# Peaks found in segment: 163
# Peaks found in segment: 142
# Peaks found in segment: 146
# Peaks found in segment: 150
# Peaks found in segment: 146
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-117/ses-01/eeg/sub-117_ses-01_task-szMonitoring_run-07_events.tsv
# sub-117_ses-01_task-szMonitoring_run-10_events.tsv: Found 3 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-117/sub-117_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 151
# Peaks found in segment: 150
# Peaks found in segment: 149
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-117/ses-01/eeg/sub-117_ses-01_task-szMonitoring_run-10_events.tsv
# sub-117_ses-01_task-szMonitoring_run-11_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-117/sub-117_ses-01_task-szMonitoring_run-11_ecg.edf
# Peaks found in segment: 153
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-117/ses-01/eeg/sub-117_ses-01_task-szMonitoring_run-11_events.tsv
# sub-118_ses-01_task-szMonitoring_run-03_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-118/sub-118_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 163
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-118/ses-01/eeg/sub-118_ses-01_task-szMonitoring_run-03_events.tsv
# sub-118_ses-01_task-szMonitoring_run-10_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-118/sub-118_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 165
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-118/ses-01/eeg/sub-118_ses-01_task-szMonitoring_run-10_events.tsv
# sub-119_ses-01_task-szMonitoring_run-28_events.tsv: Found 10 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-119/sub-119_ses-01_task-szMonitoring_run-28_ecg.edf
# Peaks found in segment: 144
# Peaks found in segment: 164
# Peaks found in segment: 157
# Peaks found in segment: 159
# Peaks found in segment: 157
# Peaks found in segment: 153
# Peaks found in segment: 164
# Peaks found in segment: 157
# Peaks found in segment: 148
# Peaks found in segment: 152
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-119/ses-01/eeg/sub-119_ses-01_task-szMonitoring_run-28_events.tsv
# sub-119_ses-01_task-szMonitoring_run-30_events.tsv: Found 2 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-119/sub-119_ses-01_task-szMonitoring_run-30_ecg.edf
# Peaks found in segment: 152
# Peaks found in segment: 151
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-119/ses-01/eeg/sub-119_ses-01_task-szMonitoring_run-30_events.tsv
# sub-119_ses-01_task-szMonitoring_run-31_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-119/sub-119_ses-01_task-szMonitoring_run-31_ecg.edf
# Peaks found in segment: 151
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-119/ses-01/eeg/sub-119_ses-01_task-szMonitoring_run-31_events.tsv
# sub-119_ses-01_task-szMonitoring_run-33_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-119/sub-119_ses-01_task-szMonitoring_run-33_ecg.edf
# Peaks found in segment: 146
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-119/ses-01/eeg/sub-119_ses-01_task-szMonitoring_run-33_events.tsv
# sub-120_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-120/sub-120_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 161
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-120/ses-01/eeg/sub-120_ses-01_task-szMonitoring_run-01_events.tsv
# sub-120_ses-01_task-szMonitoring_run-02_events.tsv: Found 5 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-120/sub-120_ses-01_task-szMonitoring_run-02_ecg.edf
# Peaks found in segment: 153
# Peaks found in segment: 147
# Peaks found in segment: 145
# Peaks found in segment: 149
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-120/ses-01/eeg/sub-120_ses-01_task-szMonitoring_run-02_events.tsv
# sub-120_ses-01_task-szMonitoring_run-03_events.tsv: Found 4 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-120/sub-120_ses-01_task-szMonitoring_run-03_ecg.edf
# Peaks found in segment: 152
# Peaks found in segment: 152
# Peaks found in segment: 147
# Peaks found in segment: 147
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-120/ses-01/eeg/sub-120_ses-01_task-szMonitoring_run-03_events.tsv
# sub-121_ses-01_task-szMonitoring_run-62_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-121/sub-121_ses-01_task-szMonitoring_run-62_ecg.edf
# Peaks found in segment: 173
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-121/ses-01/eeg/sub-121_ses-01_task-szMonitoring_run-62_events.tsv
# sub-121_ses-01_task-szMonitoring_run-64_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-121/sub-121_ses-01_task-szMonitoring_run-64_ecg.edf
# Peaks found in segment: 165
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-121/ses-01/eeg/sub-121_ses-01_task-szMonitoring_run-64_events.tsv
# sub-121_ses-01_task-szMonitoring_run-66_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-121/sub-121_ses-01_task-szMonitoring_run-66_ecg.edf
# Peaks found in segment: 164
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-121/ses-01/eeg/sub-121_ses-01_task-szMonitoring_run-66_events.tsv
# sub-121_ses-01_task-szMonitoring_run-80_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-121/sub-121_ses-01_task-szMonitoring_run-80_ecg.edf
# Peaks found in segment: 150
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-121/ses-01/eeg/sub-121_ses-01_task-szMonitoring_run-80_events.tsv
# sub-122_ses-01_task-szMonitoring_run-01_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-122/sub-122_ses-01_task-szMonitoring_run-01_ecg.edf
# Peaks found in segment: 158
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-122/ses-01/eeg/sub-122_ses-01_task-szMonitoring_run-01_events.tsv
# sub-122_ses-01_task-szMonitoring_run-10_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-122/sub-122_ses-01_task-szMonitoring_run-10_ecg.edf
# Peaks found in segment: 147
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-122/ses-01/eeg/sub-122_ses-01_task-szMonitoring_run-10_events.tsv
# sub-122_ses-01_task-szMonitoring_run-24_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-122/sub-122_ses-01_task-szMonitoring_run-24_ecg.edf
# Peaks found in segment: 95
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-122/ses-01/eeg/sub-122_ses-01_task-szMonitoring_run-24_events.tsv
# sub-122_ses-01_task-szMonitoring_run-30_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-122/sub-122_ses-01_task-szMonitoring_run-30_ecg.edf
# Peaks found in segment: 166
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-122/ses-01/eeg/sub-122_ses-01_task-szMonitoring_run-30_events.tsv
# sub-123_ses-01_task-szMonitoring_run-50_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-123/sub-123_ses-01_task-szMonitoring_run-50_ecg.edf
# Peaks found in segment: 134
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-123/ses-01/eeg/sub-123_ses-01_task-szMonitoring_run-50_events.tsv
# sub-123_ses-01_task-szMonitoring_run-81_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-123/sub-123_ses-01_task-szMonitoring_run-81_ecg.edf
# Peaks found in segment: 147
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-123/ses-01/eeg/sub-123_ses-01_task-szMonitoring_run-81_events.tsv
# sub-124_ses-01_task-szMonitoring_run-47_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-124/sub-124_ses-01_task-szMonitoring_run-47_ecg.edf
# Peaks found in segment: 148
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-124/ses-01/eeg/sub-124_ses-01_task-szMonitoring_run-47_events.tsv
# sub-125_ses-01_task-szMonitoring_run-21_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-125/sub-125_ses-01_task-szMonitoring_run-21_ecg.edf
# Peaks found in segment: 155
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-125/ses-01/eeg/sub-125_ses-01_task-szMonitoring_run-21_events.tsv
# sub-125_ses-01_task-szMonitoring_run-37_events.tsv: Found 1 seizures
# Found EDF: /content/drive/MyDrive/SeizeIT2/ECG/sub-125/sub-125_ses-01_task-szMonitoring_run-37_ecg.edf
# Peaks found in segment: 121
# Processed: /content/drive/MyDrive/SeizeIT2/seizure_events/sub-125/ses-01/eeg/sub-125_ses-01_task-szMonitoring_run-37_events.tsv
# CSV saved to /content/drive/MyDrive/SeizeIT2/preictal_rmssd_results.csv, total seizures processed: 849
